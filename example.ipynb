# %% [markdown]
# Simple test to ensure you can load the dataset

# %%
import time

from load_data import load_data

# %%
start_time = time.time()
data = load_data()
if data is not None:
    df = data
    print(f"\nDataset Loaded successfully in {time.time() - start_time:.2f} seconds")
# Out:
#
# Dataset Loaded successfully in 43.19 seconds

# %%
print(f"Total Rows: {len(df)}\n")
print(f"Dataset Columns: {df.columns.tolist()}")

df.head()
# Out:
# Total Rows: 470795
#
# Dataset Columns: ['file_url_sha16', 'file_url', 'file_path', 'file_name', 'file_sha', 'git_url', 'search_run_id', 'repo_id', 'repo_node_id', 'repo_name', 'repo_url', 'repo_homepage', 'repo_description', 'repo_fork', 'repo_private', 'repo_visibility', 'owner_login', 'owner_id', 'owner_node_id', 'owner_type', 'owner_html_url', 'owner_site_admin', 'repo_stars', 'repo_forks', 'repo_watchers', 'repo_subscribers_count', 'repo_network_count', 'repo_open_issues', 'repo_size_kb', 'repo_language', 'repo_license', 'repo_license_key', 'repo_license_spdx_id', 'repo_default_branch', 'repo_topics', 'repo_archived', 'repo_disabled', 'repo_is_template', 'repo_allow_forking', 'repo_web_commit_signoff_required', 'repo_has_issues', 'repo_has_projects', 'repo_has_wiki', 'repo_has_pages', 'repo_has_downloads', 'repo_has_discussions', 'repo_clone_url', 'repo_ssh_url', 'repo_svn_url', 'repo_git_url', 'repo_mirror_url', 'repo_created_at', 'repo_updated_at', 'repo_pushed_at', 'file_last_commit_sha', 'file_last_commit_node_id', 'file_last_commit_html_url', 'file_last_commit_message', 'file_last_commit_comment_count', 'file_last_commit_at', 'file_last_commit_author', 'file_last_commit_author_login', 'file_last_commit_author_id', 'file_last_commit_author_type', 'file_last_commit_author_html_url', 'file_last_commit_author_site_admin', 'file_last_commit_committer', 'file_last_commit_committer_at', 'file_last_commit_committer_login', 'file_last_commit_committer_id', 'file_last_commit_committer_type', 'file_last_commit_committer_html_url', 'file_last_commit_committer_site_admin', 'file_last_commit_tree_sha', 'file_last_commit_parents', 'file_last_commit_verified', 'file_last_commit_verification_reason', 'file_last_commit_verified_at', 'size_partition_label', 'updated_at', 'not_spec_filter', 'file_first_commit_sha', 'file_first_commit_node_id', 'file_first_commit_html_url', 'file_first_commit_message', 'file_first_commit_comment_count', 'file_first_commit_at', 'file_first_commit_author', 'file_first_commit_author_login', 'file_first_commit_author_id', 'file_first_commit_author_type', 'file_first_commit_author_html_url', 'file_first_commit_author_site_admin', 'file_first_commit_committer', 'file_first_commit_committer_at', 'file_first_commit_committer_login', 'file_first_commit_committer_id', 'file_first_commit_committer_type', 'file_first_commit_committer_html_url', 'file_first_commit_committer_site_admin', 'file_first_commit_tree_sha', 'file_first_commit_parents', 'file_first_commit_verified', 'file_first_commit_verification_reason', 'file_first_commit_verified_at', 'file_total_commits', 'commit_history_status', 'commit_history_fetched_at', 'spec_tool', 'spec_role', 'file_content_sha', 'file_content_bytes', 'content_fetch_status', 'content_fetched_at', 'feature_branch', 'n_linked_prs', 'n_linked_issues', 'n_sibling_docs', 'n_code_links', 'has_tasks', 'has_plan', 'has_proposal', 'has_design', 'trace_rollup_at']
#      file_url_sha16                                           file_url  \
# 0  00001a8d79a8d283  https://github.com/naigel89/CuentaMorosos/blob...
# 1  00001b3c90f61e5c  https://github.com/get2knowio/deacon/blob/d9c1...
# 2  00001d57c25efd70  https://github.com/bodangren/advantage-games/b...
# 3  000030918a44726f  https://github.com/daomar-dev/agentfleet/blob/...
# 4  0000638f415c1c6f  https://github.com/unb-mds/2026-1-LegisKids/bl...
#
#                                            file_path file_name  \
# 0  openspec/changes/payment-only-reminders/specs/...   spec.md
# 1              specs/011-update-readme-scope/spec.md   spec.md
# 2  measure/archive/competitive_multiplayer_202604...   spec.md
# 3  openspec/changes/archive/2026-04-03-merge-init...   spec.md
# 4           openspec/specs/vue-components-ui/spec.md   spec.md
#
#                                    file_sha  \
# 0  3dd8ceb07843b76fd75e61f7a994a1754000b114
# 1  1491cc3dcff0cc0068e6becf8a88f0ad859a32a6
# 2  874ffbfd76e34cf1261c599c93e036554a91abc5
# 3  982763fab898186171ac8a23153ce85bbd06ca0a
# 4  a0b72f52e7a77fe271fc8b425d8a2b5d79644d0a
#
#                                              git_url   search_run_id  \
# 0  https://api.github.com/repositories/1202132950...  spec_2024_2026
# 1  https://api.github.com/repositories/1125953734...  spec_2024_2026
# 2  https://api.github.com/repositories/1126730514...  spec_2024_2026
# 3  https://api.github.com/repositories/1207788071...  spec_2024_2026
# 4  https://api.github.com/repositories/1185583625...  spec_2024_2026
#
#       repo_id  repo_node_id                  repo_name  ...  \
# 0  1202132950  R_kgDOR6cX1g     naigel89/CuentaMorosos  ...
# 1  1125953734  R_kgDOQxywxg          get2knowio/deacon  ...
# 2  1126730514  R_kgDOQyiLEg  bodangren/advantage-games  ...
# 3  1207788071  R_kgDOR_1iJw      daomar-dev/agentfleet  ...
# 4  1185583625  R_kgDORqqSCQ   unb-mds/2026-1-LegisKids  ...
#
#             feature_branch n_linked_prs n_linked_issues  n_sibling_docs  \
# 0                     None            0               0               3
# 1  011-update-readme-scope            0               0               3
# 2                     None            0               0               1
# 3                     None            0               0               3
# 4                     None            0               0               0
#
#    n_code_links has_tasks has_plan  has_proposal has_design  \
# 0            16         1        0             1          1
# 1             0         1        1             0          0
# 2             0         0        1             0          0
# 3            14         1        0             1          1
# 4             0         0        0             0          0
#
#         trace_rollup_at
# 0  2026-07-21T17:18:38Z
# 1  2026-07-21T17:18:38Z
# 2  2026-07-21T17:18:38Z
# 3  2026-07-21T17:18:38Z
# 4  2026-07-21T17:18:38Z
#
# [5 rows x 124 columns]
